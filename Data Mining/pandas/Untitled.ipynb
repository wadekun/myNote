# %%
import pandas as pd
pd.set_option('display.mpl_style', 'default')  # 使图表更漂亮
# %matplotlib inline
# Out:
# /Users/liangck/anaconda2/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2862: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df = pd.read_csv('./comptagevelo20162.csv', parse_dates=['Date'], index_col='Date', dayfirst=True)
#df['Berri1']
df[0:1]
# Out:
#            Unnamed: 1  Berri1  Boyer  Brébeuf  CSC (Côte Sainte-Catherine)  \
# Date
# 2016-01-01      00:00      32      0       27                          0.0
#
#             Maisonneuve_2  Maisonneuve_3  Notre-Dame  Parc  PierDup  \
# Date
# 2016-01-01           51.0             16           1     5        1
#
#             Pont_Jacques_Cartier  Rachel / Hôtel de Ville  Rachel / Papineau  \
# Date
# 2016-01-01                    13                      NaN                 93
#
#             René-Lévesque  Saint-Antoine  Saint-Urbain  Totem_Laurier  \
# Date
# 2016-01-01             12              6            38             68
#
#             University  Viger
# Date
# 2016-01-01          14     11

# %%
df['Berri1'].plot()
